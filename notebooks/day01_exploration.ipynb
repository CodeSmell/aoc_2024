# %% [markdown]
# # Day 1 Exploration - Learning Step by Step
#
# This notebook is for exploring Advent of Code Day 1 problem. We'll take it slow and learn:
# - How to read and understand the problem
# - How to explore the input data
# - How to build a solution step by step
# - How to test our solution
# - How to write clean, readable code
#
# Remember: The goal is learning, not just solving!

# %% [markdown]
# ## 1. Import Required Libraries
#
# Let's start simple. We'll import only what we need and understand what each library does.

# %%
# Basic imports - start simple!
import os          # For file operations
from pathlib import Path  # Modern way to handle file paths

# Let's understand what we imported
print("Current working directory:", os.getcwd())
print("Path to this notebook:", Path.cwd())

# We'll add more imports as we need them

# %% [markdown]
# ## 2. Understanding the Problem
#
# **Step 1:** Copy the problem description here when Day 1 is released.
#
# **Step 2:** Break down what the problem is asking:
# - What is the input format?
# - What do we need to calculate?
# - What is the expected output?
#
# **Step 3:** Look at the example and trace through it manually.

# %%
# Let's create a simple example to work with
# Replace this with the actual example when Day 1 is released

example_input = """1000
2000
3000

4000

5000
6000

7000
8000
9000

10000"""

print("Example input:")
print(example_input)
print("\nLet's understand this data:")
print(f"- Total length: {len(example_input)} characters")
print(f"- Number of lines: {len(example_input.splitlines())}")
print(f"- Has empty lines: {'\\n\\n' in example_input}")
